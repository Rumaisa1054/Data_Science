# %% [markdown]
# <a href="https://colab.research.google.com/github/Rumaisa1054/Data_Science/blob/main/stats_visuals/stats/Sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | Feature              | Representative Sampling                            | Non-Representative Sampling                                  |
# | -------------------- | -------------------------------------------------- | ------------------------------------------------------------ |
# | Reflects population? | ✅ Yes                                              | ❌ No                                                         |
# | Bias                 | Low                                                | High                                                         |
# | Generalization       | Accurate                                           | Misleading                                                   |
# | Example              | Stratified sample matching population demographics | Survey only college students when studying national opinions |
# ![image.png](data:image/png;base64,...)

# %%
# purposive sampling / judgemental sampling- we know we need only albinos we we gather data abou them only
# haphhazard sampling : finding people randomly and getting their data
# convienience samplimg /snowball samlping: taking data from people whose data is easier to get -- then asking them to share other persons to find more data

# %%
# simple random sampling: every individial has equal chance to be selected

# systematic samplng  : Selecting every nth person from a sample

# stratified sampling : dividing the population into small groups(Strata) and then samples are taken from each stratum
# Example - dividing by age and then selecting few people of every age

# cluster sampling: dividing population into clusters and then randomly selecting entire clusters
# Example dividing a city into neighborhoods nad then selecting few entire neighborbood individuals

# hybrid sampling - example stratified sampling with random sampling

# %% [markdown]
# # **Types of statistics**
# --------------------------------------------
# **Statistics** : collecting - analyzing - interpretting - presenting - organizing data
#
# ----------------------------------------------
# **Data has 4 ways to be explored**
# 1. composition
# 2. distribution
# 3. comparison
# 4. relationship
#
# --------------------------------------------
# **descriptive statistics**
#
# 1. summarize  (mean - med - mod)
# 2. describe (variance - std - se - range)
# 3. explore (data_type of features,shape of data , dist)
# 4. univariate analysis (data dist - outliers)
# 5. bivariate analysis (co-relation, relationship)
# 6. multi-variate analysis
# 7. knitty-gritties
# 8. features

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Descriptive statistics - Main points**
#
# 1. Population vs Sample - meaning
# 2. Central tendency ( mean - median - mode)
# 3. Measure of variability (variance - std - se)
# 4. outliers
# 5. data visualization ( freq table i.e value_counts() - plots - bar_charts/histogram/boxplot)
# 6. bivariate_plots (scatter, line chart)
# 7. You can compare means as well once you got them : Inferential stats
# 8. In EDA, we can do all variability,distribution,binary vs categorical, corelation,comparision
# 9. In descriptive stats, if we are only comparing not talking about the population from a sample, rather jsut comparing two groups then we can put it in descriptive stats. Example suppose mean of female spending is 30k and mean of male spending is 20k, then we can say that women on average spend 10k more than men. but we are only talking on basis of mean. we could have considered other things like std
# 10. z-test and t-test are here for it for comparing mean correctly

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# if population_mean known and n > 30 ---> z-test else t-test
# z-test used when samples > 30
# t_test used when samples < 30

# one sample : compare mean of age a group vs known value ( age = 50)
# two sample : comparing mean of age of male and female ( both are independent)

# paired t-test / repeated measure:
# Use Case: When the same subjects (or matched pairs) are measured twice, e.g., before-and-after studies.
# Comparing the average age of people in 2013 vs average age of the same people in 2022 (longitudinal study).
# dependeent
