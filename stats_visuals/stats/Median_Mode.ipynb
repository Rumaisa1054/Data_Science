# %% [markdown]
# <a href="https://colab.research.google.com/github/Rumaisa1054/Data_Science/blob/main/stats_visuals/stats/Median_Mode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# no impact of outliers
# median - sort all values and select middle one
# if n = even middle_elements are two so take their mean (middle1 + middle2)/2
# else median = middle element

# people use median to impute null values

# %%
import numpy as np
import pandas as pd
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
from scipy import stats
df['fare'].median()
# Out:
# 14.4542

# %%
# for categorical data you can use mode -- the value having most frequency
# if some categorical varibales have same frequency you can prefer them on basis of index
df['class'].mode()
# Out:
# 0    Third
# Name: class, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
print(df['class'].mode()[0])
# Out:
# Third

# %%
df['class'].nunique()
# Out:
# 3

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# numeric data - mean median
# categorical - mode
# we use them in null
'''
population mean uses meu  and N
sample mean uses x_bar and n
'''

# we have to think beyod average -
# variance or spreas should be studied -

#  key terms that help us understand variance
#  1. Range : Minimum data value - Max data value
#  2. IQR : Middle 50% data
#  3. variance :
#  4. standard deviation
#  5. standard error
